# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
files = os.listdir('TestPredictions/')[:-2]

# %%
files
# Out:
# ['subject_009_01__y_prediction.csv',
#  'subject_010_01__y_prediction.csv',
#  'subject_011_01__y_prediction.csv',
#  'subject_012_01__y_prediction.csv']

# %%
for file in files:
    data = pd.read_csv('TestPredictions/'+file, header=None)
    data.plot()

# %%
y_files = os.listdir('Y_data/')

# %%
for file in y_files:
    data = pd.read_csv('Y_data/'+file, header=None)
    data.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
